# %% [markdown]
# # Tutorial - Machine Learning para Economistas
# ## Tutorial 2
#
# - Conocer qué son y cómo trabajar con APIs

# %% [markdown]
# ¿Qué es una API? Los sistemas tienen distintos tipos de interfaces que permiten interactuar con ellos.
#
# * **GUI (Graphical User Interface o interfaz gráfica)**: El usuario clickea e interactúa con distintos objetos para ejecutar acciones y lograr sus objetivos. Las páginas web tienen interfaces gráficas.
# * **API (Application Programming Interface o interfaz de programación)**: El usuario escribe líneas de código para interactuar con el sistema, ejecutar acciones y lograr sus objetivos.
#
# Todos los sitios web tienen una interfaz gráfica con la que estamos acostumbrados a interactuar, y también tienen una interfaz de programación más o menos desarrollada, o más o menos expuesta, con la cual tal vez no estemos tan acostumbrados a interactuar.
#
# Ejemplo:
#
# En https://www.mercadolibre.com.ar/ podemos buscar en el buscador "pelotas", apretar "Enter" y el sistema devuelve el resultado de una búsqueda. Si, en cambio, ponemos por "pelotas futbol" y apretamos "Enter" de nuevo, cambiará el resultado de la búsqueda. Esta es la **interfaz gráfica del sitio**.
#
# Sin embargo, también podríamos lograr el mismo objetivo sólo escribiendo distintas URLs en el navegador:
#
# * https://listado.mercadolibre.com.ar/pelotas
# * https://listado.mercadolibre.com.ar/pelotas-futbol
#
# Esto es más parecido a lo que llamaríamos una **interfaz de programación**.

# %% [markdown]
# Las APIs son mecanismos que permiten que una aplicación o servicio acceda a un recurso en otra aplicación o servicio (un cliente accede a recurso en un servidor).
#
# En la web, las interfaces de programación de uso más difundido son las APIs REST ([Representational state transfer](https://es.wikipedia.org/wiki/Transferencia_de_Estado_Representacional)). REST es un estilo para diseñar aplicaciones que especifica un conjunto de protocolos y métodos para interactuar con los recursos de internet escribiendo líneas de código.
#
# Estas APIs se comunican mediante el protocolo HTTP para interactuar con los recursos (es el medio de comunicación comunicación entre el usuario y el servidor). HTTP es el mismo protocolo que se utiliza para cargar páginas web en un navegador.
# Este protocolo indica cómo estructurar un mensaje de texto que describa la petición (**request**) del usuario o cliente a un servidor. Hay distintos tipos de peticiones que un usuario puede realizar, algunas de ellas son:
#
# * **POST**: Envía datos al servidor para crear un recurso nuevo.
# * **GET**: Se utiliza para obtener información de un recurso alojado en el servidor.
# * **PUT**: Actualiza (crea o modifica) un recurso del servidor.
# * **DELETE**: Elimina un recurso del servidor.
#
# El cliente manda una petición (**request**) y el servidor devuelve una respuesta (**response**).
#
# <font color="gray">
# Fuente: Curso de Instituto Humai - APIs
# <font>

# %% [markdown]
# Cada vez que vamos al navegador y escribimos la dirección de una página web, **estamos haciendo un GET request** a un servidor. Esto es una petición para adquirir el código de un recurso que queremos visualizar en el navegador.
#
# La URL es la parte más importante de la definición de un GET request (aunque el navegador agrega otras cosas también, que no vemos) y nos permite cambiar la representación deseada de un mismo recurso de distintas maneras:
#
# * https://deportes.mercadolibre.com.ar/pelotas-futbol pide al servidor pelotas de fútbol.
# * https://deportes.mercadolibre.com.ar/pelotas-futbol_OrderId_PRICE pide al servidor pelotas de fútbol ordenadas por precio.
#
# Cuando escribimos una URL en un navegador, la mayoría de las veces hacemos GET requests que devuelven código HTML (el código que da una estructura a una página web, tal como vimos en el video anterior cuando obteníamos el código HTML al hacer web scraping). Pero los GET requests pueden devolver datos en otros formatos (por ejemplo en JSON y en CSV).
#
# Las APIs REST que definen GET requests capaces de devolver datos en formato JSON y CSV, son particularmente útiles cuando queremos analizar datos.
#
# Ahora vamos a conocer algunas APIs.

# %% [markdown]
# ### Vamos a usar la API de Mercado Libre
#
# En particular, vamos a:
# - ver los resultados de una búsqueda
# - obtener la descripción de una publicación
#
# Para ver más información ir a: https://developers.mercadolibre.com.ar/

# %%
import requests

# %% [markdown]
# #### Obtener ítems de una consulta de búsqueda
#
# - https://developers.mercadolibre.com.ar/es_ar/items-y-busquedas
#
# Con el parámetro “q” puedes realizar una búsqueda por palabra, frases o tributos claves de búsqueda. Es importante tener en cuenta que en este campo puedes enviar tantos detalles de los atributos de la publicación como sea necesario, de esta manera en la respuesta obtendrás búsquedas más precisas. Si quieres separar términos puedes usar %20 que corresponde al código ASCII.
#
# ![meli_items.JPG](attachment:meli_items.JPG)

# %%
# Así se ve la búsqueda en el navegador:
# https://listado.mercadolibre.com.ar/libro-introduction-to-statistical-learning

# Al usar la API tenemos que seguir este formato:
# https://api.mercadolibre.com/sites/$SITE_ID/search?q=nombre%20item

# Notar que:
# $SITE_ID: MLA  # MLA es el sitio de Argentina
# item: item a buscar. (reemplazamos los espacios con %20)

buscar = "libro introduction to statistical learning"
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20"))

# Hacemos el pedido o request y obtenemos la response
response = requests.request("GET", url)
print(response) # correcto

# Vemos el texto
response.text
# Out:
# <Response [200]>
# '{"site_id":"MLA","country_default_time_zone":"GMT-03:00","query":"libro introduction to statistical learning","paging":{"total":115,"primary_results":12,"offset":0,"limit":50},"results":[{"id":"MLA1388764527","title":" An Introduction To Statistical Learning: With Applications","condition":"new","thumbnail_id":"954833-MLM45501945224_042021","catalog_product_id":"MLA21541174","listing_type_id":"gold_special","permalink":"https://www.mercadolibre.com.ar/an-introduction-to-statistical-learning-with-applications/p/MLA21541174","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA412445","domain_id":"MLA-BOOKS","thumbnail":"http://http2.mlstatic.com/D_954833-MLM45501945224_042021-I.jpg","currency_id":"ARS","order_backend":1,"price":181630,"original_price":null,"sale_price":null,"available_quantity":1,"official_store_id":3073,"official_store_name":"LIBERATE","use_thumbnail_id":true,"accepts_mercadopago":true,"shipping":{"store_pick_up":false,"free_shipping":true,"logistic_type":"cross_docking","mode":"me2","tags":["mandatory_free_shipping"],"benefits":null,"promise":null},"stop_time":"2043-09-13T04:00:00.000Z","seller":{"id":385635403,"nickname":"LIBERATE_ARG"},"attributes":[{"id":"BRAND","name":"Marca","value_id":null,"value_name":"Springer-Verlag New York Inc.","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"Springer-Verlag New York Inc.","struct":null,"source":8482906911511018}],"source":8482906911511018,"value_type":"string"},{"id":"ITEM_CONDITION","name":"Condición del ítem","value_id":"2230284","value_name":"Nuevo","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"2230284","name":"Nuevo","struct":null,"source":1}],"source":1,"value_type":"list"},{"id":"MODEL","name":"Modelo","value_id":null,"value_name":"Gareth James","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":null,"name":"Gareth James","struct":null,"source":8482906911511018}],"source":8482906911511018,"value_type":"string"},{"id":"PACKAGE_LENGTH","name":"Largo del paquete","value_id":null,"value_name":"20 cm","attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":{"number":20,"unit":"cm"},"values":[{"id":null,"name":"20 cm","struct":{"number":20,"unit":"cm"},"source":8482906911511018}],"source":8482906911511018,"value_type":"number_unit"},{"id":"PACKAGE_WEIGHT","name":"Peso del paquete","value_id":"-1","value_name":null,"attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"-1","name":null,"struct":null,"source":8482906911511018}],"source":8482906911511018,"value_type":"number_unit"},{"id":"WEIGHT","name":"Peso","value_id":"-1","value_name":null,"attribute_group_id":"OTHERS","attribute_group_name":"Otros","value_struct":null,"values":[{"id":"-1","name":null,"struct":null,"source":8482906911511018}],"source":8482906911511018,"value_type":"number_unit"}],"installments":{"quantity":6,"amount":48107.73,"rate":58.92,"currency_id":"ARS"},"winner_item_id":null,"catalog_listing":true,"discounts":null,"promotions":[],"inventory_id":null},{"id":"MLA1121313969","title":"Book : Introduction To Statistical And Machine Learning...","condition":"new","thumbnail_id":"941934-MLA48975429910_012022","catalog_product_id":null,"listing_type_id":"gold_special","permalink":"https://articulo.mercadolibre.com.ar/MLA-1121313969-book-introduction-to-statistical-and-machine-learning-_JM","buying_mode":"buy_it_now","site_id":"MLA","category_id":"MLA412445","domain_id":"MLA-BOOKS","thumbnail":"http://http2.mlstatic.com/D_941934-MLA48975429910_012022-I.jpg","currency_id":"ARS","order_backend":2,"price":147999,"original_price":null,"sale_price":null,"available_quantity":1,"official_store_id":null,"use_thumbnail_id":true,"accepts_mercadopago":true,"shipping":{"store_pick_up":false,"free_shipping":true,"logistic_type":"cross_docking","mode":"me2","tags":["mandatory_free_shipp ...

# %%
url
# Out:
# 'https://api.mercadolibre.com/sites/MLA/search?q=libro%20introduction%20to%20statistical%20learning'

# %%
# Pero podríamos guardar el resultado en un diccionario (json)
data = response.json()
#type(data) # dict
data
# Out:
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'libro introduction to statistical learning',
#  'paging': {'total': 115, 'primary_results': 12, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLA1388764527',
#    'title': ' An Introduction To Statistical Learning: With Applications',
#    'condition': 'new',
#    'thumbnail_id': '954833-MLM45501945224_042021',
#    'catalog_product_id': 'MLA21541174',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/an-introduction-to-statistical-learning-with-applications/p/MLA21541174',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_954833-MLM45501945224_042021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 181630,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 3073,
#    'official_store_name': 'LIBERATE',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2043-09-13T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'Springer-Verlag New York Inc.',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Springer-Verlag New York Inc.',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Gareth James',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Gareth James',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'number': 20, 'unit': 'cm'},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 48107.73,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1121313969',
#    'title': 'Book : Introduction To Statistical And Machine Learning...',
#    'condition': 'new',
#    'thumbnail_id': '941934-MLA48975429910_012022',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1121313969-book-introduction-to-statistical-and-machine-learning-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_941934-MLA48975429910_012022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 147999,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-01-25T04:00:00.000Z',
#    'seller': {'id': 161008662, 'nickname': 'ELBAZARDIGITAL'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'SAS Institute',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'SAS Institute',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Ingles',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Ingles',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'string'}],
#    'installments': {'quantity': 6,
#     'amount': 39200,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1675597856',
#    'title': 'Book: An Introduction To Statistical Learning: With Appli...',
#    'condition': 'new',
#    'thumbnail_id': '629500-MLA74630117149_022024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1675597856-book-an-introduction-to-statistical-learning-with-appli-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_629500-MLA74630117149_022024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 504369,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-02-15T04:00:00.000Z',
#    'seller': {'id': 161008662, 'nickname': 'ELBAZARDIGITAL'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '187938',
#      'value_name': 'Springer',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '187938',
#        'name': 'Springer',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': '3031387465',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '3031387465',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'string'}],
#    'installments': {'quantity': 6,
#     'amount': 133590.54,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA663837518',
#    'title': 'Book : An Introduction To Statistical Learning: With Appl...',
#    'condition': 'new',
#    'thumbnail_id': '621726-MLA26737981176_012018',
#    'catalog_product_id': 'MLA21541174',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-663837518-book-an-introduction-to-statistical-learning-with-appl-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_621726-MLA26737981176_012018-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 506639,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2037-04-21T14:51:05.000Z',
#    'seller': {'id': 161008662, 'nickname': 'ELBAZARDIGITAL'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '187938',
#      'value_name': 'Springer',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '187938',
#        'name': 'Springer',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': '37236906',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '37236906',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '0.97 kg',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 0.97, 'unit': 'kg'},
#      'values': [{'id': None,
#        'name': '0.97 kg',
#        'struct': {'number': 0.97, 'unit': 'kg'},
#        'source': 1183438784296846}],
#      'source': 1183438784296846,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 134191.78,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1621817338',
#    'title': 'An Introduction To Statistical Learning: With Applications I',
#    'condition': 'new',
#    'thumbnail_id': '986817-MLA73752351954_012024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1621817338-an-introduction-to-statistical-learning-with-applications-i-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_986817-MLA73752351954_012024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 307040,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-01-01T04:00:00.000Z',
#    'seller': {'id': 110992, 'nickname': 'LECTURA.OK'},
#    'attributes': [{'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 377188858949192}],
#      'source': 377188858949192,
#      'value_type': 'list'}],
#    'installments': {'quantity': 6,
#     'amount': 81324.66,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1675666092',
#    'title': 'Book: An Introduction To Statistical Learning / Python',
#    'condition': 'new',
#    'thumbnail_id': '640568-MLA74632365977_022024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1675666092-book-an-introduction-to-statistical-learning-python-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_640568-MLA74632365977_022024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 384000,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-02-15T04:00:00.000Z',
#    'seller': {'id': 110992, 'nickname': 'LECTURA.OK'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '187938',
#      'value_name': 'Springer',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '187938',
#        'name': 'Springer',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': '3031387465',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '3031387465',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'}],
#    'installments': {'quantity': 6,
#     'amount': 101708.8,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1644833382',
#    'title': 'Introduction To Statistical Machine Learning (en Inglés) / M',
#    'condition': 'new',
#    'thumbnail_id': '848615-MLA74118514934_012024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1644833382-introduction-to-statistical-machine-learning-en-ingles-m-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_848615-MLA74118514934_012024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 532200,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-01-20T04:00:00.000Z',
#    'seller': {'id': 110992, 'nickname': 'LECTURA.OK'},
#    'attributes': [{'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 377188858949192}],
#      'source': 377188858949192,
#      'value_type': 'list'}],
#    'installments': {'quantity': 6,
#     'amount': 140962.04,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA916515928',
#    'title': 'An Introduction To Statistical Learning : With Applicatio...',
#    'condition': 'new',
#    'thumbnail_id': '859536-MLA45592995233_042021',
#    'catalog_product_id': 'MLA21541174',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-916515928-an-introduction-to-statistical-learning-with-applicatio-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_859536-MLA45592995233_042021-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 251047,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 3073,
#    'official_store_name': 'LIBERATE',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2041-04-11T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'Springer-Verlag New York Inc.',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Springer-Verlag New York Inc.',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Gareth James',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Gareth James',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'number': 20, 'unit': 'cm'},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 66493.98,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1260393847',
#    'title': 'Libro Introduction To Statistical And Machine Learning Me...',
#    'condition': 'new',
#    'thumbnail_id': '791222-MLA52609650441_112022',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1260393847-libro-introduction-to-statistical-and-machine-learning-me-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_791222-MLA52609650441_112022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 9,
#    'price': 82996,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 3073,
#    'official_store_name': 'LIBERATE',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-11-21T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Carlos Andre Reis Pinheiro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Carlos Andre Reis Pinheiro',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'number': 20, 'unit': 'cm'},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 21982.87,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA845605183',
#    'title': 'Introduction To Statistical Machine Learning - Masashi Su...',
#    'condition': 'new',
#    'thumbnail_id': '685162-MLA44293842529_122020',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-845605183-introduction-to-statistical-machine-learning-masashi-su-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_685162-MLA44293842529_122020-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 10,
#    'price': 359972,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 3073,
#    'official_store_name': 'LIBERATE',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2040-03-22T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'ELSEVIER SCIENCE & TECHNOLOGY',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'ELSEVIER SCIENCE & TECHNOLOGY',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Masashi Sugiyama',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Masashi Sugiyama',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'unit': 'cm', 'number': 20},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '1089 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 1089, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '1089 g',
#        'struct': {'number': 1089, 'unit': 'g'},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 95344.58,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA848826851',
#    'title': 'An Elementary Introduction To Statistical Learning Theory...',
#    'condition': 'new',
#    'thumbnail_id': '978260-MLA31051981267_062019',
#    'catalog_product_id': 'MLA31630901',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-848826851-an-elementary-introduction-to-statistical-learning-theory-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_978260-MLA31051981267_062019-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 11,
#    'price': 358053,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2040-04-07T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'John Wiley & Sons Inc',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'John Wiley & Sons Inc',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Sanjeev Kulkarni',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Sanjeev Kulkarni',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'number': 20, 'unit': 'cm'},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '499 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 499, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '499 g',
#        'struct': {'number': 499, 'unit': 'g'},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 94836.3,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1260580126',
#    'title': 'Libro Introduction To Statistical And Machine Learning Me...',
#    'condition': 'new',
#    'thumbnail_id': '651216-MLA52609649622_112022',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1260580126-libro-introduction-to-statistical-and-machine-learning-me-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_651216-MLA52609649622_112022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 12,
#    'price': 108790,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-11-21T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Carlos Andre Reis Pinheiro',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Carlos Andre Reis Pinheiro',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'number': 20, 'unit': 'cm'},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 28814.84,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1683337158',
#    'title': 'Connectionist, Statistical And Symbolic Approaches To Learning For Natural Language Processing, De Stefan Wermter. Editorial Springer-verlag Berlin And Heidelberg Gmbh & Co. Kg, Tapa Blanda En Inglés',
#    'condition': 'new',
#    'thumbnail_id': '964848-MLU74512793093_022024',
#    'catalog_product_id': 'MLA32938565',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/connectionist-statistical-and-symbolic-approaches-to-learning-for-natural-language-processing-de-stefan-wermter-editorial-springer-verlag-berlin-and-heidelberg-gmbh-co-kg-tapa-blanda-en-ingles/p/MLA32938565',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_964848-MLU74512793093_022024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 13,
#    'price': 153869,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 3073,
#    'official_store_name': 'LIBERATE',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-02-21T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'Springer-Verlag Berlin and Heidelberg GmbH & Co. KG',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Springer-Verlag Berlin and Heidelberg GmbH & Co. KG',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Stefan Wermter',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Stefan Wermter',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'unit': 'cm', 'number': 20},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 40754.77,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1683508980',
#    'title': 'Case-based Predictions: An Axiomatic Approach To Prediction, Classification And Statistical Learning, De Itzhak Gilboa. Editorial World Scientific Publishing Co Pte Ltd, Tapa Dura En Inglés',
#    'condition': 'new',
#    'thumbnail_id': '893498-MLU74237028135_012024',
#    'catalog_product_id': 'MLA30321755',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/case-based-predictions-an-axiomatic-approach-to-prediction-classification-and-statistical-learning-de-itzhak-gilboa-editorial-world-scientific-publishing-co-pte-ltd-tapa-dura-en-ingles/p/MLA30321755',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_893498-MLU74237028135_012024-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 14,
#    'price': 375280,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': 3073,
#    'official_store_name': 'LIBERATE',
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2044-02-21T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'World Scientific Publishing Co Pte Ltd',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'World Scientific Publishing Co Pte Ltd',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Itzhak Gilboa',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Itzhak Gilboa',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'number': 20, 'unit': 'cm'},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 99399.16,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': True,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1129490515',
#    'title': 'Book : Introduction To Public Health - Schneider, Mary-jane',
#    'condition': 'new',
#    'thumbnail_id': '643460-MLA49492173075_032022',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1129490515-book-introduction-to-public-health-schneider-mary-jane-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_643460-MLA49492173075_032022-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 15,
#    'price': 277999,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2042-03-22T04:00:00.000Z',
#    'seller': {'id': 161008662, 'nickname': 'ELBAZARDIGITAL'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'Jones & Bartlett Learning',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Jones & Bartlett Learning',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'Ingles',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Ingles',
#        'struct': None,
#        'source': 2775198729990532}],
#      'source': 2775198729990532,
#      'value_type': 'string'}],
#    'installments': {'quantity': 6,
#     'amount': 73632.67,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1490251748',
#    'title': "Introduction To Machine Learning With Python : A Guide For Data Scientists, De Sarah Guido. Editorial O'reilly Media, Inc, Usa, Tapa Blanda En Inglés",
#    'condition': 'new',
#    'thumbnail_id': '960249-MLU69666938501_052023',
#    'catalog_product_id': 'MLA23505788',
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://www.mercadolibre.com.ar/introduction-to-machine-learning-with-python-a-guide-for-data-scientists-de-sarah-guido-editorial-oreilly-media-inc-usa-tapa-blanda-en-ingles/p/MLA23505788',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_960249-MLU69666938501_052023-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 16,
#    'price': 247549,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
# ...
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_681065-MLA43051974661_082020-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 49,
#    'price': 54839,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2040-08-01T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'John Slavio',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'John Slavio',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'John Slavio',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'John Slavio',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'unit': 'cm', 'number': 20},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 14525.02,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA876505145',
#    'title': 'Machine Learning For Beginners : An Introduction To Artif...',
#    'condition': 'new',
#    'thumbnail_id': '885390-MLA43352857667_092020',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-876505145-machine-learning-for-beginners-an-introduction-to-artif-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA412445',
#    'domain_id': 'MLA-BOOKS',
#    'thumbnail': 'http://http2.mlstatic.com/D_885390-MLA43352857667_092020-I.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 50,
#    'price': 96484,
#    'original_price': None,
#    'sale_price': None,
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': True,
#    'accepts_mercadopago': True,
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'cross_docking',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None},
#    'stop_time': '2040-08-29T04:00:00.000Z',
#    'seller': {'id': 385635403, 'nickname': 'LIBERATE_ARG'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'value_name': 'John Slavio',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'John Slavio',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'list'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'John Slavio',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'John Slavio',
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'string'},
#     {'id': 'PACKAGE_LENGTH',
#      'name': 'Largo del paquete',
#      'value_id': None,
#      'value_name': '20 cm',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 20, 'unit': 'cm'},
#      'values': [{'id': None,
#        'name': '20 cm',
#        'struct': {'unit': 'cm', 'number': 20},
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'PACKAGE_WEIGHT',
#      'name': 'Peso del paquete',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '-1',
#      'value_name': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '-1',
#        'name': None,
#        'struct': None,
#        'source': 8482906911511018}],
#      'source': 8482906911511018,
#      'value_type': 'number_unit'}],
#    'installments': {'quantity': 6,
#     'amount': 25555.4,
#     'rate': 58.92,
#     'currency_id': 'ARS'},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None}],
#  'sort': {'id': 'relevance', 'name': 'Más relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor precio'},
#   {'id': 'price_desc', 'name': 'Mayor precio'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MLA412445',
#      'name': 'Libros Físicos',
#      'path_from_root': [{'id': 'MLA3025', 'name': 'Libros, Revistas y Comics'},
#       {'id': 'MLA412445', 'name': 'Libros Físicos'}]}]}],
#  'available_filters': [{'id': 'state',
#    'name': 'Ubicación',
#    'type': 'text',
#    'values': [{'id': 'TUxBUENBUGw3M2E1',
#      'name': 'Capital Federal',
#      'results': 12},
#     {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 5},
#     {'id': 'TUxBUFNBTm5lYjU4', 'name': 'San Juan', 'results': 1}]},
#   {'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 43},
#     {'id': '3073', 'name': 'LIBERATE', 'results': 43}]},
#   {'id': 'price',
#    'name': 'Precio',
#    'type': 'range',
#    'values': [{'id': '*-150000.0', 'name': 'Hasta $ 150.000', 'results': 38},
#     {'id': '150000.0-300000.0', 'name': '$150.000 a $300.000', 'results': 44},
#     {'id': '300000.0-*', 'name': 'Más de $300.000', 'results': 39}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con MercadoPago', 'results': 115}]},
#   {'id': 'installments',
#    'name': 'Financiación',
#    'type': 'text',
#    'values': [{'id': 'yes', 'name': 'En cuotas', 'results': 65}]},
#   {'id': 'shipping',
#    'name': 'Envío',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envíos',
#      'results': 115}]},
#   {'id': 'power_seller',
#    'name': 'Filtro por calidad de vendedores',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 104}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicaciones con video',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Publicaciones con video', 'results': 1}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicaciones con imágenes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con fotos', 'results': 115}]},
#   {'id': 'shipping_cost',
#    'name': 'Costo de envío',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 113}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 113},
#     {'id': '2230581', 'name': 'Usado', 'results': 2}]},
#   {'id': 'LANGUAGE',
#    'name': 'Idioma',
#    'type': 'STRING',
#    'values': [{'id': '313885', 'name': 'Inglés', 'results': 114}]},
#   {'id': 'MIN_RECOMMENDED_AGE',
#    'name': 'Edad mínima recomendada',
#    'type': 'range',
#    'values': [{'id': '(*-6meses)', 'name': 'Menos de 6 meses', 'results': 98},
#     {'id': '[2años-18años)', 'name': '2 a 17 años', 'results': 1},
#     {'id': '[18años-*)', 'name': '18 años o más', 'results': 1}]},
#   {'id': 'NARRATION_TYPE',
#    'name': 'Tipo de narración',
#    'type': 'STRING',
#    'values': [{'id': '19916122', 'name': 'Libro', 'results': 80},
#     {'id': '7488906', 'name': 'Novela', 'results': 3},
#     {'id': '7488907', 'name': 'Manual', 'results': 1},
#     {'id': '20129535', 'name': 'Narrativa', 'results': 1}]},
#   {'id': 'product',
#    'name': 'Producto',
#    'type': 'text',
#    'values': [{'id': 'MLA21541174',
#      'name': ' An Introduction To Statistical Learning: With Applications',
#      'results': 3},
#     {'id': 'MLA23505776',
#      'name': "Introduction to Machine Learning with Python : A Guide for Data Scientists. Sarah Guido. Inglés. O'Reilly Media, Inc, USA",
#      'results': 2},
#     {'id': 'MLA23505788',
#      'name': "Introduction To Machine Learning With Python : A Guide For Data Scientists, De Sarah Guido. Editorial O'reilly Media, Inc, Usa, Tapa Blanda En Inglés",
#      'results': 2},
#     {'id': 'MLA29894420',
#      'name': "Hergenhahn's An Introduction To The History Of Psychology, De Tracy Henley. Editorial Cengage Learning, Inc, Tapa Dura En Inglés",
#      'results': 1},
#     {'id': 'MLA30321755',
#      'name': 'Case-based Predictions: An Axiomatic Approach To Prediction, Classification And Statistical Learning, De Itzhak Gilboa. Editorial World Scientific Publishing Co Pte Ltd, Tapa Dura En Inglés',
#      'results': 1},
#     {'id': 'MLA30568092',
#      'name': 'Introduction To Statistical Physics, De Silvio Salinas. Editorial Springer-verlag New York Inc., Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA30660509',
#      'name': 'Introduction To Image Processing Using R : Learning By Examples, De Alejandro C. Frery. Editorial Springer London Ltd, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA31164152',
#      'name': 'An Introduction To Six Sigma And Process Improvement, De James R. Evans. Editorial Cengage Learning, Inc, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA31189104',
#      'name': 'Entropy And The Tao Of Counting : A Brief Introduction To Statistical Mechanics And The Second La..., De Kim Sharp. Editorial Springer Nature Switzerland Ag, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA31238533',
#      'name': 'Machine Learning And Statistical Modeling Approaches To Image Retrieval, De Yixin Chen. Editorial Springer-verlag New York Inc., Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA31255275',
#      'name': 'Introduction To Deep Learning Using R : A Step-by-step Guide To Learning And Implementing Deep Le..., De Taweh Beysolow Ii. Editorial Apress, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA31293491',
#      'name': 'An Introduction To Policing, De Linda Forst. Editorial Cengage Learning Inc, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA31330320',
#      'name': 'Statistical Physics And Thermodynamics : An Introduction To Key Concepts, De Jochen Rau. Editorial Oxford University Press, Tapa Dura En Inglés',
#      'results': 1},
#     {'id': 'MLA31382666',
#      'name': 'An Introduction To Statistical Signal Processing, De Robert M. Gray. Editorial Cambridge University Press, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA31552663',
#      'name': 'Introduction To Statistical Physics, De Silvio R.a. Salinas. Editorial Springer-verlag New York Inc., Tapa Dura En Inglés',
#      'results': 1},
#     {'id': 'MLA31630901',
#      'name': 'An Elementary Introduction To Statistical Learning Theory, De Sanjeev Kulkarni. Editorial John Wiley & Sons Inc, Tapa Dura En Inglés',
#      'results': 1},
#     {'id': 'MLA31936715',
#      'name': 'Introduction To Business Management (principles Of Management), De National Learning Corporation. Editorial National Learning Corp, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA31964529',
#      'name': 'Introduction To Statistical Pattern Recognition, De Keinosuke Fukunaga. Editorial Elsevier Science Publishing Co Inc, Tapa Dura En Inglés',
#      'results': 1},
#     {'id': 'MLA32201995',
#      'name': 'Learning To Use Statistical Tests In Psychology, De Judith Greene. Editorial Open University Press, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA32694571',
#      'name': 'An Introduction To Statistical Modelling, De W. J. Krzanowski. Editorial John Wiley & Sons Inc, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA32717962',
#      'name': 'Introduction To Brain-compatible Learning, De Eric P. Jensen. Editorial Sage Publications Inc, Tapa Dura En Inglés',
#      'results': 1},
#     {'id': 'MLA32938565',
#      'name': 'Connectionist, Statistical And Symbolic Approaches To Learning For Natural Language Processing, De Stefan Wermter. Editorial Springer-verlag Berlin And Heidelberg Gmbh & Co. Kg, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA33044890',
#      'name': 'Body Learning : An Introduction To The Alexander Technique, De Michael Gelb. Editorial Henry Holt & Company Inc, Tapa Blanda En Inglés, 1996',
#      'results': 1},
#     {'id': 'MLA33204420',
#      'name': 'Introduction To Statistical Reasoning, De Gary Smith. Editorial Createspace Independent Publishing Platform, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA33317179',
#      'name': 'Introduction To Machine Learning In Quantitative Finance, An, De Hao Ni. Editorial World Scientific Europe Ltd, Tapa Blanda En Inglés',
#      'results': 1},
#     {'id': 'MLA33494437',
#      'name': 'An Introduction To Multivariate Statistical Analysis, De T. W. Anderson. Editorial John Wiley & Sons Inc, Tapa Dura En Inglés',
#      'results': 1}]}],
#  'pdp_tracking': {'group': False,
#   'product_info': [{'id': 'MLA21541174', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA32938565', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA30321755', 'score': 1, 'status': 'shown'},
#    {'id': 'MLA23505788', 'score': 1, 'status': 'shown'}]}}

# %%
# Ahora podemos acceder a los distintos resultados (usando las keys del diccionario), por ejemplo:

# Vemos la longitud de la lista de resultados
print('Longitud de lista de resultados:', len(data['results']))

# Vemos el precio del primer resultado de la búsqueda
print('Precio del primer resultado:', data['results'][0]['price'])

# Link del primer resultado
print(data['results'][0]['permalink'])
# Out:
# Longitud de lista de resultados: 50
# Precio del primer resultado: 181630
# https://www.mercadolibre.com.ar/an-introduction-to-statistical-learning-with-applications/p/MLA21541174

# %% [markdown]
# #### Consultar descripción de un ítem
#
# - https://developers.mercadolibre.com.ar/en_us/item-description-2

# %%
# Al usar la API tenemos que seguir este formato:
#https://api.mercadolibre.com/items/$ITEM_ID/description

# Veamos un ejemplo con el primer item que aparece al buscar el libro
print(data['results'][0]['id'])
print(data['results'][0]['permalink'])
#https://articulo.mercadolibre.com.ar/MLA-1121313969-book-introduction-to-statistical-and-machine-learning-_JM#position=3&search_layout=stack&type=item&tracking_id=05f493fb-55d2-468b-896f-8a1890e10e65v
# Vemos que
# $ITEM_ID es MLA1121313969 # no se pone el guion medio

url = "https://api.mercadolibre.com/items/{}{}/description".format("MLA", '1121313969')
response2 = requests.get(url)
response2.text
# Out:
# MLA1388764527
# https://www.mercadolibre.com.ar/an-introduction-to-statistical-learning-with-applications/p/MLA21541174
# '{"text":"","plain_text":"- ANTES DE COMPRAR PREGUNTE FECHA DE ENTREGA.\\r\\n- ENVIAMOS POR MERCADOENVIOS\\r\\n- PUEDE RETIRAR POR AHORA SOLO POR QUILMES, MICROCENTRO ESTA CERRADO, POR ESO...\\r\\n- EN CABA (CAPITAL FEDERAL) ENVIAMOS SIN CARGO ESTE PRODUCTO.\\r\\n- FORMA DE PAGO : MERCADOPAGO\\r\\n- HACEMOS FACTURA A.\\r\\n- ELBAZARDIGITAL VENDEDOR PLATINUM\\r\\n- TODOS NUESTROS PRODUCTOS EN:\\r\\n\\r\\nhttps://eshops.mercadolibre.com.ar/elbazardigital\\r\\n\\r\\n-X-X-X-\\r\\n\\r\\n- SOMOS IMPORTADORES DIRECTOS, ESTE PRODUCTO SE COMPRA Y SE IMPORTA DESDE ESTADOS UNIDOS, ESTO IMPLICA QUE USTED ESTA COMPRANDO EL MISMO PRODUCTO QUE COMPRARÍA UN CLIENTE DE ESE PAÍS.\\r\\n\\r\\n- ANTES DE REALIZAR UNA CONSULTA, VISUALICE TODAS LAS IMAGENES DEL PRODUCTO.\\r\\nDescripción provista por la editorial :\\n\\n Boost your understanding of data science techniques to solve real-world problems Data science is an exciting, interdisciplinary field that extracts insights from data to solve business problems. This book introduces common data science techniques and methods and shows you how to apply them in real-world case studies. From data preparation and exploration to model assessment and deployment, this book describes every stage of the analytics life cycle, including a comprehensive overview of unsupervised and supervised machine learning techniques. The book guides you through the necessary steps to pick the best techniques and models and then implement those models to successfully address the original business need. No software is shown in the book, and mathematical details are kept to a minimum. This allows you to develop an understanding of the fundamentals of data science, no matter what background or experience level you have.  About the Author Dr. Carlos Andre Reis Pinheiro is a Principal Data Scientist at SAS and a Visiting Professor at Data ScienceTech Institute in France. He has been working in analytics since 1996 for some of the largest telecommunications providers in Brazil in multiple roles from technical to executive. He worked as a Senior Data Scientist for EMC in Brazil on network analytics, optimization, and text analytics projects, and as a Lead Data Scientist for Teradata on machine learning projects. Dr. Pinheiro has a BSc in Applied Mathematics and Computer Science, an MSc in Computing, and a DSc in Engineering from the Federal University of Rio de Janeiro. Carlos has completed a series of postdoctoral research terms in different fields, including Dynamic Systems at IMPA, Brazil; Social Network Analysis at Dublin City University, Ireland; Transportation Systems at Universite de Savoie, France; Dynamic Social Networks and Human Mobility at Katholieke Universiteit Leuven, Belgium; and Urban Mobility and Multi-modal Traffic at Fundaçao Getulio Vargas, Brazil. He has published several papers in international journals and conferences, and he is author of Social Network Analysis in Telecommunications and Heuristics in Analytics: A Practical Perspective of What Influence Our Analytical World, both published by John Wiley and Sons, Inc.Michael Patetta has been a statistical instructor for SAS since 1994. He teaches a variety of courses including Supervised Machine Learning Procedures Using SAS Viya in SAS Studio, Predictive Modeling Using Logistic Regression, Introduction to Data Science Statistical Methods, and Regression Methods Using SAS Viya. Before coming to SAS, Michael worked in the North Carolina State Health Department for 10 years as a health statistician and program manager. He has authored or co-authored 10 published papers since 1983. Michael has a BA from the University of Notre Dame and a MA from the University of North Carolina at Chapel Hill. In his spare time, he loves to hike in National Parks.\\n-o-o-o-","last_updated":"2022-01-30T20:50:03.000Z","date_created":"2022-01-30T20:50:03.000Z","snapshot":{"url":"http://descriptions.mlstatic.com/D-MLA1121313969.jpg?hash=8520c3b8559cb08aa7e782b8f5334ffe_0x0","width" ...

# %% [markdown]
# ### API Series de Tiempo
#
# La **[API Series de Tiempo de la Republica Argentina](https://apis.datos.gob.ar/series)** es una API REST desarrollada y mantenida por el Estado Nacional de Argentina para la consulta de estadísticas en formato de series de tiempo. Contiene series publicadas por organismos de la Administración Pública Nacional.
#
# La API permite:
#
# * [Buscar series](https://datosgobar.github.io/series-tiempo-ar-api/reference/search-reference/) por texto. También se pueden buscar en el sitio web de datos.gob.ar: https://datos.gob.ar/series
# * Cambiar la frecuencia (por ejemplo: convertir series diarias en mensuales)
# * Elegir la función de agregacion de valores, usada en el cambio de frecuencia (una serie se puede convertir de diaria a mensual promediando, sumando, sacando el maximo, el minimo, el ultimo valor del periodo, etc)
# * Filtrar por rango de fechas
# * Elegir el formato (CSV o JSON)
# * Cambiar configuracion del CSV (caracter separador, caracter decimal)
#
# En https://datos.gob.ar/series podés buscar series de tiempo publicadas por distintos organismos de la Administración Pública Nacional en Argentina y usar el link al CSV para leerlos directamente desde python con pandas.
#
# También podes **buscar los ids de las series de interés** y juntarlos en la misma consulta para armar una tabla de hasta 40 series.

# %%
# Un ejemplo

url_arg = "https://apis.datos.gob.ar/series/api/series?ids=102.1_I2NG_ABRI_M_22,101.1_I2NG_2016_M_22&format=json"

response = requests.get(url_arg)
print(response)

datos = response.json()
datos
# Out:
# <Response [200]>
# {'data': [['2004-01-01', None, None, 92.62750602691052],
#   ['2004-02-01', None, None, 90.1861793165596],
#   ['2004-03-01', None, None, 101.88329804238072],
#   ['2004-04-01', None, None, 102.5674302511826],
#   ['2004-05-01', None, None, 109.87750394051662],
#   ['2004-06-01', None, None, 105.66240620209852],
#   ['2004-07-01', None, None, 101.1069972900212],
#   ['2004-08-01', None, None, 98.35573694243756],
#   ['2004-09-01', None, None, 98.08637453469638],
#   ['2004-10-01', None, None, 97.8356659809799],
#   ['2004-11-01', None, None, 100.1319466812214],
#   ['2004-12-01', None, None, 101.67895479099536],
#   ['2005-01-01', None, None, 98.473359529179],
#   ['2005-02-01', None, None, 96.11886613343404],
#   ['2005-03-01', None, None, 110.65642586719524],
#   ['2005-04-01', None, None, 116.54519048214908],
#   ['2005-05-01', None, None, 126.66194335502726],
#   ['2005-06-01', None, None, 116.50222321492876],
#   ['2005-07-01', None, None, 107.58113926245956],
#   ['2005-08-01', None, None, 105.82089279310112],
#   ['2005-09-01', None, None, 104.89213472672316],
#   ['2005-10-01', None, None, 104.4606653849844],
#   ['2005-11-01', None, None, 108.00375438454834],
#   ['2005-12-01', None, None, 110.50332389924424],
#   ['2006-01-01', None, None, 106.53094787692405],
#   ['2006-02-01', None, None, 104.0901370432872],
#   ['2006-03-01', None, None, 118.58827645043104],
#   ['2006-04-01', None, None, 122.08710730131628],
#   ['2006-05-01', None, None, 133.37101567477424],
#   ['2006-06-01', None, None, 124.29274775102324],
#   ['2006-07-01', None, None, 117.0456318535268],
#   ['2006-08-01', None, None, 116.30360797574892],
#   ['2006-09-01', None, None, 114.80248033323907],
#   ['2006-10-01', None, None, 116.47750825324565],
#   ['2006-11-01', None, None, 118.14078229406633],
#   ['2006-12-01', None, None, 119.60317208093002],
#   ['2007-01-01', None, None, 114.70176482722368],
#   ['2007-02-01', None, None, 112.74324828605302],
#   ['2007-03-01', None, None, 129.28276498944658],
#   ['2007-04-01', None, None, 133.46308313008805],
#   ['2007-05-01', None, None, 147.60791074167545],
#   ['2007-06-01', None, None, 136.12098630494512],
#   ['2007-07-01', None, None, 127.3875518979554],
#   ['2007-08-01', None, None, 126.59522767863],
#   ['2007-09-01', None, None, 123.5104632944452],
#   ['2007-10-01', None, None, 128.41538266104467],
#   ['2007-11-01', None, None, 129.73508945617357],
#   ['2007-12-01', None, None, 128.89792837498598],
#   ['2008-01-01', None, None, 126.22689251081432],
#   ['2008-02-01', None, None, 122.8249045091645],
#   ['2008-03-01', None, None, 132.33412728743554],
#   ['2008-04-01', None, None, 145.28049855207212],
#   ['2008-05-01', None, None, 154.15616391286648],
#   ['2008-06-01', None, None, 140.50348421669764],
#   ['2008-07-01', None, None, 136.63868805371584],
#   ['2008-08-01', None, None, 131.34092143552698],
#   ['2008-09-01', None, None, 132.18593848988462],
#   ['2008-10-01', None, None, 130.39517884255912],
#   ['2008-11-01', None, None, 125.52756329262156],
#   ['2008-12-01', None, None, 123.46600579407662],
#   ['2009-01-01', None, None, 116.7584192020652],
#   ['2009-02-01', None, None, 114.85886148592792],
#   ['2009-03-01', None, None, 126.16560261026108],
#   ['2009-04-01', None, None, 127.9905588745035],
#   ['2009-05-01', None, None, 133.03567047814315],
#   ['2009-06-01', None, None, 129.31265804805898],
#   ['2009-07-01', None, None, 127.3630583750141],
#   ['2009-08-01', None, None, 124.00328620894652],
#   ['2009-09-01', None, None, 126.18512812472764],
#   ['2009-10-01', None, None, 127.07986188269524],
#   ['2009-11-01', None, None, 127.09219178029132],
#   ['2009-12-01', None, None, 126.28656380555832],
#   ['2010-01-01', None, None, 121.50567852923164],
#   ['2010-02-01', None, None, 119.82280209203972],
#   ['2010-03-01', None, None, 136.89550162046118],
#   ['2010-04-01', None, None, 145.77413149301782],
#   ['2010-05-01', None, None, 158.1106315304388],
#   ['2010-06-01', None, None, 149.86155200805445],
#   ['2010-07-01', None, None, 139.50568662872732],
#   ['2010-08-01', None, None, 137.24598068715568],
#   ['2010-09-01', None, None, 136.69642672162283],
#   ['2010-10-01', None, None, 135.13884450692316],
#   ['2010-11-01', None, None, 139.59882328372225],
#   ['2010-12-01', None, None, 138.47764951271685],
#   ['2011-01-01', None, None, 133.0769197185519],
#   ['2011-02-01', None, None, 129.50988684262188],
#   ['2011-03-01', None, None, 147.00183909502377],
#   ['2011-04-01', None, None, 151.03582303961804],
#   ['2011-05-01', None, None, 166.17834208101743],
#   ['2011-06-01', None, None, 156.69365851225533],
#   ['2011-07-01', None, None, 146.37808828046835],
#   ['2011-08-01', None, None, 146.3985053847187],
#   ['2011-09-01', None, None, 147.170906821271],
#   ['2011-10-01', None, None, 145.0500024277993],
#   ['2011-11-01', None, None, 146.3616451241655],
#   ['2011-12-01', None, None, 143.36165785374328],
#   ['2012-01-01', None, None, 136.19408129361287],
#   ['2012-02-01', None, None, 132.3605259407412],
#   ['2012-03-01', None, None, 147.44101624495764],
#   ['2012-04-01', None, None, 145.52027831854522]],
#  'count': 247,
#  'meta': [{'frequency': 'month',
#    'start_date': '2004-01-01',
#    'end_date': '2012-04-01'},
#   {'catalog': {'title': 'Datos Programación Macroeconómica'},
#    'dataset': {'title': 'Índice de Precios al Consumidor GBA (IPC-GBA). Base diciembre 2016.',
#     'description': 'Índice de Precios al Consumidor del Gran Buenos Aires. Apertura por capítulos. Base diciembre 2016.',
#     'issued': '2017-09-28',
#     'source': 'Instituto Nacional de Estadística y Censos (INDEC)'},
#    'distribution': {'title': 'Índice de Precios al Consumidor. Bienes y servicios. Base diciembre 2016. Valores mensuales',
#     'downloadURL': 'https://infra.datos.gob.ar/catalog/sspm/dataset/101/distribution/101.3/download/indice-precios-al-consumidor-bienes-servicios-base-diciembre-2016-mensual.csv'},
#    'field': {'description': 'IPC-GBA. Nivel General. Base abr 2016. Mensual',
#     'id': '102.1_I2NG_ABRI_M_22',
#     'units': 'Índice Dic-2016=100',
#     'representation_mode': 'value',
#     'representation_mode_units': 'Índice Dic-2016=100'}},
#   {'catalog': {'title': 'Datos Programación Macroeconómica'},
#    'dataset': {'title': 'Índice de Precios al Consumidor GBA (IPC-GBA). Base diciembre 2016.',
#     'description': 'Índice de Precios al Consumidor del Gran Buenos Aires. Apertura por capítulos. Base diciembre 2016.',
#     'issued': '2017-09-28',
#     'source': 'Instituto Nacional de Estadística y Censos (INDEC)'},
#    'distribution': {'title': 'Índice de Precios al Consumidor, por capítulos. Base  diciembre 2016. Valores mensuales',
#     'downloadURL': 'https://infra.datos.gob.ar/catalog/sspm/dataset/101/distribution/101.1/download/indice-precios-al-consumidor-apertura-por-capitulos-base-diembre-2016-mensual.csv'},
#    'field': {'description': 'IPC-GBA. Nivel General. Base dic 2016. Mensual',
#     'id': '101.1_I2NG_2016_M_22',
#     'units': 'Índice Dic-2016=100',
#     'representation_mode': 'value',
#     'representation_mode_units': 'Índice Dic-2016=100'}},
#   {'catalog': {'title': 'Datos Programación Macroeconómica'},
#    'dataset': {'title': 'Estimador Mensual de Actividad Económica (EMAE). Base 2004',
#     'description': 'Índice original Estimador Mensual de Actividad Económica. Índice (Base 2004)',
#     'issued': '2017-09-28',
#     'source': 'Instituto Nacional de Estadística y Censos (INDEC)'},
#    'distribution': {'title': 'EMAE. Índice Base 2004.Valores mensuales.',
#     'downloadURL': 'https://infra.datos.gob.ar/catalog/sspm/dataset/143/distribution/143.3/download/emae-valores-anuales-indice-base-2004-mensual.csv'},
#    'field': {'description': 'EMAE. Base 2004',
#     'id': '143.3_NO_PR_2004_A_21',
#     'units': 'Índice 2004=100',
#     'representation_mode': 'value',
#     'representation_mode_units': 'Índice 2004=100'}}],
#  'params': {'ids': '102.1_I2NG_ABRI_M_22,101.1_I2NG_2016_M_22,143.3_NO_PR_2004_A_21',
#   'format': 'json',
#   'identifiers': [{'id': '102.1_I2NG_ABRI_M_22',
#     'distribution': '101.3',
#     'dataset': '101'},
#    {'id': '101.1_I2NG_2016_M_22', 'distribution': '101.1', 'dataset': '101'},
#    {'id': '143.3_NO_PR_2004_A_21',
#     'distribution': '143.3',
#     'dataset': '143'}]}}

# %%
d  = datos['data']

import pandas as pd

hola = pd.DataFrame(d)

# %%
hola
# Out:
#              0     1     2           3
# 0   2004-01-01  None  None   92.627506
# 1   2004-02-01  None  None   90.186179
# 2   2004-03-01  None  None  101.883298
# 3   2004-04-01  None  None  102.567430
# 4   2004-05-01  None  None  109.877504
# ..         ...   ...   ...         ...
# 95  2011-12-01  None  None  143.361658
# 96  2012-01-01  None  None  136.194081
# 97  2012-02-01  None  None  132.360526
# 98  2012-03-01  None  None  147.441016
# 99  2012-04-01  None  None  145.520278
#
# [100 rows x 4 columns]
